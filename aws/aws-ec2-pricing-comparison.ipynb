# %% [markdown]
# # AWS EC2 Pricing Comparison

# %% [markdown]
# ## Analytics

# %% [markdown]
# ### Parameters

# %%
# Data on disk
LOCAL_OFFER_FILE = 'data/ec2.json'

# Fetch from AWS
INDEX_BASE_URL = "https://pricing.us-east-1.amazonaws.com"
INDEX_PATH = "/offers/v1.0/aws/index.json"
SERVICE_CODE = "AmazonEC2"

# OS
OPERATING_SYSTEM = 'Linux'

# Location filter criteria
ALLOW_LOCATION_TYPE = ('AWS Region',)
DENY_LOCATION = ('AWS GovCloud (US)',)

# Something unique as magic string that doesn't collide
UNIQUE_STR = "*SDN+.@"

# %% [markdown]
# ### Constants

# %%
ENUM_SIZE = {
    'micro': 1,
    'small': 2,
    'medium': 4,
    'large': 8,
    'xlarge': 16,
    '2xlarge': 32,
    '4xlarge': 64,
    '8xlarge': 128,
    '10xlarge': 160,
}

# %% [markdown]
# ### Imports and functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os, json

# %%
def json_fetch(url):
    """
    Fetch json from url, return parsed data structure
    """
    import requests
    return json.loads(requests.get(url).text)
    
def load_ec2_pricing():
    if LOCAL_OFFER_FILE and os.path.isfile(LOCAL_OFFER_FILE):
        with open(LOCAL_OFFER_FILE) as fp:
            return json.load(fp)
    
    offer_index = json_fetch(INDEX_BASE_URL + INDEX_PATH)
    return json_fetch(INDEX_BASE_URL + offer_index['offers'][SERVICE_CODE]['currentVersionUrl'])

def convolute(data, *functions):
    ptr = data
    for fp in functions:
        ptr = fp(ptr)
    
    return ptr

def explode_instance_type(instance_type):
    return instance_type.split('.')

# %%
def filter_prod_compute(products):
    return {
        k: v for k, v in products.items() if
        v['productFamily'] == 'Compute Instance' and v['attributes'].get('tenancy', '') == 'Shared'
    }

def filter_prod_os(products):
    return {
        k: v for k, v in products.items() if
        v['attributes'].get('operatingSystem', UNIQUE_STR) == OPERATING_SYSTEM
    }

def filter_prod_location(products):
    return {
        k: v for k, v in products.items() if
        'locationType' in v['attributes'] and 
        'location' in v['attributes'] and
        v['attributes']['locationType'] in ALLOW_LOCATION_TYPE and 
        v['attributes']['location'] not in DENY_LOCATION
    }

def filtergen_prod_tenancy(tenancy):
    return lambda products: {
        k: v for k, v in products.items() if
        v['attributes'].get('tenancy', UNIQUE_STR) == tenancy
    }

# %% [markdown]
# ### Load Data from Disk or AWS

# %%
pricing = load_ec2_pricing()
products = convolute(
    pricing['products'],
    filter_prod_compute,
    filter_prod_os,
    filter_prod_location,
    filtergen_prod_tenancy('Shared'),
)

products_categorized = {}
for p in products.values():
    i_family, i_type = explode_instance_type(p['attributes']['instanceType'])
    products_categorized \
        .setdefault(p['attributes']['location'], {}) \
        .setdefault(i_family, {})[i_type] = p['sku']

# %% [markdown]
# {{len(pricing['products'])}} product entries found, {{len(products)}} among {{len(products_categorized)}} regions passed filtering criteria.

# %%
products_categorized
# Out:
# {'Asia Pacific (Singapore)': {'c1': {'medium': 'YDP6BX3WNNZ488BZ',
#    'xlarge': '8V5MYBMPUD434579'},
#   'c3': {'2xlarge': 'PJ8AKRU5VVMS9DFN',
#    '4xlarge': 'UKY8RWKR7MVYC863',
#    '8xlarge': 'XUVJRQ9MSAQKDXE9',
#    'large': 'ABMNUJ6SQ7A595A4',
#    'xlarge': 'G9Z5RTPAVX5KWH4Z'},
#   'c4': {'2xlarge': 'UKGPAABCGR48DYC4',
#    '4xlarge': '3ZUGJVTA8NWE9NZT',
#    '8xlarge': 'Z3DQKNTFUZ68H6TT',
#    'large': 'QB3EG2XVBQ5BYA5F',
#    'xlarge': 'U9CPUKN22CXMPGRV'},
#   'd2': {'2xlarge': 'SKTEJ2QN2YW8UFKF',
#    '4xlarge': 'M5ZT2V2ZMSBCEB2Q',
#    '8xlarge': 'EEUHF7PCXDQT2MYE',
#    'xlarge': 'DTZY5KW9NPT6V929'},
#   'g2': {'2xlarge': 'VVKTWPMARM4HESXU', '8xlarge': 'DK6FJW8STXUGW6PA'},
#   'hs1': {'8xlarge': 'EERGZVYFKRBMSYKW'},
#   'i2': {'2xlarge': 'DKFKKEAW78H8X64T',
#    '4xlarge': '8E9KB9CNE94Z4AHE',
#    '8xlarge': 'VE5MWWHUXS2VR8DV',
#    'xlarge': 'GCVKBN38AXXGHBQH'},
#   'm1': {'large': '2B4AFZB6SYHMPZGS',
#    'medium': '7FQD2RCMJSS57GFA',
#    'small': '6R4QVUNHTJVS9J2S',
#    'xlarge': '7TMGTEJPM5UPWQ8X'},
#   'm2': {'2xlarge': 'TYGKARPH33A4B8DT',
#    '4xlarge': 'Y3RWQDFC7G8TZ3A8',
#    'xlarge': '39ZR86RYWKDSK82K'},
#   'm3': {'2xlarge': 'R8K75VHRAADAJJ2W',
#    'large': 'YSKUUH777M98DWE4',
#    'medium': 'ZAGTVD3ADUUPS6QV',
#    'xlarge': '8VCD85YY26XCKZDE'},
#   'm4': {'10xlarge': 'AEUJF75AZR2WPVWK',
#    '2xlarge': 'UKF69K7GTUQKKRPH',
#    '4xlarge': '5ES8X7PS795W6ZD4',
#    'large': 'B9DFHMNNN499Z259',
#    'xlarge': 'N55SZ6XU92JF33VX'},
#   'r3': {'2xlarge': 'SMHSRASDZ66J6CC3',
#    '4xlarge': 'KCZD349CGXR5DRQ3',
#    '8xlarge': 'JDH4WM7E92WUS9JS',
#    'large': 'EV2HH2XUX6RZEAW3',
#    'xlarge': 'P6BPTANASQKJ8FJX'},
#   't1': {'micro': 'J65Z38YCBYKP7Q49'},
#   't2': {'large': 'UYUWYNASFB3J75S6',
#    'medium': 'J23MFJ7UXYN9HFKS',
#    'micro': 'RZV9MRNEARCGY297',
#    'small': '7QHAUE39SCU6N9N9'}},
#  'Asia Pacific (Sydney)': {'c1': {'medium': 'T72BQ8E4ETD9K62R',
#    'xlarge': 'CMDB58FT3PAJJNGN'},
#   'c3': {'2xlarge': 'R8KMJWXSQ8BJC35M',
#    '4xlarge': 'N32CG42C5KFN6GDH',
#    '8xlarge': 'FYMCPD2A3YBTSUPQ',
#    'large': '8XZUT4AHDH972AME',
#    'xlarge': 'XPAKDV3PWHYTJU3X'},
#   'c4': {'2xlarge': 'FFBDA7VFHVPEJXS6',
#    '4xlarge': 'F9BAR5QA2VU3ZTBF',
#    '8xlarge': '46ZVWU6WX68NZCE7',
#    'large': '2PKSXUFC38ZY888Q',
#    'xlarge': 'XD4VKMMZMCMZYFWJ'},
#   'd2': {'2xlarge': 'CP3U32VDAT67RT9R',
#    '4xlarge': 'MSGAHYMZTGGJN5WS',
#    '8xlarge': 'KEVDJ9YEEGJZZGDS',
#    'xlarge': 'HDSPKHDAUP2HXQTR'},
#   'g2': {'2xlarge': 'DS7EYGXHAG6T6NTV', '8xlarge': 'TD8NW4BSBCYU646U'},
#   'hs1': {'8xlarge': '5BKJJZ77BSJPMR4D'},
#   'i2': {'2xlarge': '6CK52R5BRMQEVGRW',
#    '4xlarge': '6UHS7YAMM8JY7X52',
#    '8xlarge': 'RW8353QQ8DWZ4WQD',
#    'xlarge': 'FJURXZQ9HT9HN2YJ'},
#   'm1': {'large': 'KWTW9RNYJG6GG3J2',
#    'medium': 'TPJVBXMBFDUBJM83',
#    'small': 'VM2PFN8ME9595UGP',
#    'xlarge': '8A5X9KQR4YKYYXCQ'},
#   'm2': {'2xlarge': '6PB95M6GG8CNXMMR',
#    '4xlarge': '4PRF9CZZBT3AM9D4',
#    'xlarge': 'V5SUYWWSC9HUZFWJ'},
#   'm3': {'2xlarge': 'D29U26UAEX6WK4TW',
#    'large': 'HHJGN8MDU3U6DFE5',
#    'medium': '6WEMUEK6JNZU6PTC',
#    'xlarge': '69UM5U8QFXRAU255'},
#   'm4': {'10xlarge': 'SPJKFAB8G379JD6R',
#    '2xlarge': '296YCXVCWAKPXKRE',
#    '4xlarge': 'C4A5RM72TUGX8R5D',
#    'large': '6UMTMKVFBXENW3BF',
#    'xlarge': 'RAWDW374YPCAB65D'},
#   'r3': {'2xlarge': 'WNYWP7QUJ3MU8NVV',
#    '4xlarge': 'DBMRRDDSPZZKNV49',
#    '8xlarge': 'GKVR3QEC5B7WJXTD',
#    'large': 'N3D6SQF6HU9ENSPR',
#    'xlarge': 'KNJZFWCSBKY8N4NF'},
#   't1': {'micro': '9CYSN2TKZDN6GFWQ'},
#   't2': {'large': 'JT2PVSWTGS2BMV4D',
#    'medium': 'ZNG78GP248PZPM6R',
#    'micro': '7NYHPHSMD45SYSNN',
#    'small': 'E6JQJZ8BQHCG328E'}},
#  'Asia Pacific (Tokyo)': {'c1': {'medium': 'PTSCWYT4DGMHMSYG',
#    'xlarge': 'URZU4GXQC7AT6RE9'},
#   'c3': {'2xlarge': 'YR67H6NVBRN37HRZ',
#    '4xlarge': 'XJ88E6MSR3AYHFXA',
#    '8xlarge': 'E3J2T7B8EQDFXWDR',
#    'large': 'Q4QTSF7H37JFW9ER',
#    'xlarge': 'HTNXMK8Z5YHMU737'},
#   'c4': {'2xlarge': 'Q85F79PK8VHHZT6X',
#    '4xlarge': 'E5MWNHYU3BAVZCRP',
#    '8xlarge': 'PCNBVATW49APFGZQ',
#    'large': '7KXQBZSKETPTG6QZ',
#    'xlarge': 'UJB452HW969DQZFB'},
#   'cc2': {'8xlarge': 'YJ2E4JTYGN2FMNQM'},
#   'cr1': {'8xlarge': 'GP8GQA2T96JQ4MBB'},
#   'd2': {'2xlarge': '7A24VVDQEZ54FYXU',
#    '4xlarge': '6JP9PA73B58NZHUN',
#    '8xlarge': 'PSF2TQK8WMUGUPYK',
#    'xlarge': 'VWWQ7S3GZ9J8TF77'},
#   'g2': {'2xlarge': '77K4UJJUNGQ6UXXN', '8xlarge': 'CTK39QJHQN4CZ3PC'},
#   'hi1': {'4xlarge': 'M3G65XHCPFQHAQD5'},
#   'hs1': {'8xlarge': '8H36QJ2PHPR3SJ48'},
#   'i2': {'2xlarge': 'KM8DYQWHEC32CGGX',
#    '4xlarge': 'FBUWUPNC8FXRUS5W',
#    '8xlarge': '4REMK3MMXCZ55ZX3',
#    'xlarge': 'EZCSGZJ8PMXA2QF2'},
#   'm1': {'large': '6TMC6UD2UCCDAMNP',
#    'medium': 'F2RRJYX33EGMBSFR',
#    'small': 'AKQ89V8E78T6H534',
#    'xlarge': '4BJPFU3PAZJ4AKMM'},
#   'm2': {'2xlarge': 'UMV7384WFS5N9T5F',
#    '4xlarge': 'BQQUCAM9PFTSUNQX',
#    'xlarge': 'G6G6ZNFBYMW2V8BH'},
#   'm3': {'2xlarge': 'PCB5ARVZ6TNS7A96',
#    'large': 'AY6XZ64M22QQJCXE',
#    'medium': '6M27QQ6HYCNA5KGA',
#    'xlarge': 'J85A5X44TT267EH8'},
#   'm4': {'10xlarge': 'JTQKHD7ZTEEM4DC5',
#    '2xlarge': '4GHFAT5CNS2FEKB2',
#    '4xlarge': 'XU2NYYPCRTK4T7CN',
#    'large': '7MYWT7Y96UT3NJ2D',
#    'xlarge': 'BURRP7APFUCZFSZK'},
#   'r3': {'2xlarge': '9KMZWGZVTXKAQXNM',
#    '4xlarge': 'BYV8H4R4VJNAH42Q',
#    '8xlarge': 'DDX2JPPMM28BXD7D',
#    'large': 'YCYU3NQCQRYQ2TU7',
#    'xlarge': 'GJHUHQSUU37VCQ5A'},
#   't1': {'micro': 'ERVWZ4V3UBYH4NQH'},
#   't2': {'large': 'Q5HVB8NUA7UMHV4Y',
#    'medium': 'E6F66FZ47YZNXAJ2',
#    'micro': '9NSP3EV3G593P35X',
#    'small': 'YUYNTU8AZ9MKK68V'}},
#  'EU (Frankfurt)': {'c3': {'2xlarge': 'MB3JDB58W76ZHFT8',
#    '4xlarge': 'N7WSYHVUT72KMK3V',
#    '8xlarge': 'KYFX85FCPCCT57BD',
#    'large': '686NEEYZAPY5GJ8N',
#    'xlarge': 'HW3SH7C5H3K3MV7E'},
#   'c4': {'2xlarge': 'NZS3Z83VUDZA9SPY',
#    '4xlarge': 'ATHMXFEBFCM8TPWK',
#    '8xlarge': 'D8BFUEFHTHMN4XUY',
#    'large': 'WWTVB5GY85P5FGNW',
#    'xlarge': 'ZAC36C46HPYXADA7'},
#   'd2': {'2xlarge': '6Y959B8MKQZ55MGT',
#    '4xlarge': '5RNA3KEVYJW8UJWT',
#    '8xlarge': 'F5FY39C3HWRVW8M7',
#    'xlarge': 'FXJNETA7Z34Z9BAR'},
#   'i2': {'2xlarge': 'FECZ7UBC3GFUYSJC',
#    '4xlarge': '4TT65SC5HVYUSGR2',
#    '8xlarge': 'SMTUMBHX6YKRBJQB',
#    'xlarge': 'N2333QQ45Q3K9RT9'},
#   'm3': {'2xlarge': 'CNP4PV4Y2J8YZVAR',
#    'large': '8KTQAHWA58GUHDGC',
#    'medium': 'GDZZPNEEZXAN7X9J',
#    'xlarge': '5ZZCF2WTD3M2NVHT'},
#   'm4': {'10xlarge': 'XWVCP8TVZ3EZXHJT',
#    '2xlarge': 'CDQ3VSAVRNG39R6V',
#    '4xlarge': 'JGXEWM5NJCZJPHGG',
#    'large': 'ABFDCPB959KUGRH8',
#    'xlarge': 'EF7GKFKJ3Y5DM7E9'},
#   'r3': {'2xlarge': 'MTQWAHX8C4T4FYVW',
#    '4xlarge': '3KCGMZRVWDY4AC5R',
#    '8xlarge': '3AFDFDJ9FGMNBBUZ',
#    'large': 'JG83GAMRHT9DJ8TH',
#    'xlarge': 'ER456JE239VN5TQY'},
#   't2': {'large': '7W6DNQ55YG9FCPXZ',
#    'medium': '5P7657GQ9EZ2Z4ZY',
#    'micro': 'T9GCN3NZ9U6N5BGN',
#    'small': 'CU49Z77S6UH36JXW'}},
#  'EU (Ireland)': {'c1': {'medium': 'HB5V2X8TXQUTDZBV',
#    'xlarge': 'WTE2TS5FTMMJQXHK'},
#   'c3': {'2xlarge': 'P75KF3MVS7BD8VRA',
#    '4xlarge': '926EPQHVQ6AGDX5P',
#    '8xlarge': 'YT7Q7XWV392U2M45',
#    'large': 'RASFAC97JWEGEPYS',
#    'xlarge': 'WDZRKB8HUJXEKH45'},
#   'c4': {'2xlarge': 'V2SRX3YBPSJPD8E4',
#    '4xlarge': 'BG8E99UBN6RZV6WV',
#    '8xlarge': 'YMCJTDYUBRJ9G3JJ',
#    'large': 'XWEGA3UJZ88J37T5',
#    'xlarge': 'V4Q928Z7YAM3TJ6X'},
#   'cc2': {'8xlarge': 'T3ZC3B9VPS8PA59H'},
#   'cg1': {'4xlarge': '3H8WR8FBAE4DWNRB'},
#   'cr1': {'8xlarge': 'FSS42UA3US5PWMV7'},
#   'd2': {'2xlarge': '2SX63SRBXZK94TSA',
#    '4xlarge': '6HX9NKE3BQ5V3PMJ',
#    '8xlarge': 'NV44PJXFFQV9UNQZ',
#    'xlarge': '9VHN6EZGZGFZEHHK'},
#   'g2': {'2xlarge': 'VM3SRW97DB2T2U8Z', '8xlarge': 'E9FTXSZ49KS3R3HY'},
#   'hi1': {'4xlarge': 'YVBHSQT9PFQ3DB5S'},
#   'hs1': {'8xlarge': 'TDVRYW6K68T4XJHJ'},
#   'i2': {'2xlarge': 'DYTSK9JJGPSR6VQB',
#    '4xlarge': 'EQP9JWYVRCW49MPW',
#    '8xlarge': 'ADT8TJSCKTFKTBMX',
#    'xlarge': 'KKQD5EPCF8JFUDDA'},
#   'm1': {'large': 'NSCRWEDQZZESFDFG',
#    'medium': 'YC9UG3ESW33SS2WK',
#    'small': 'EB2QM2B74W2YCANP',
#    'xlarge': '9QYQQRQ9FD9YCPNB'},
#   'm2': {'2xlarge': 'P7JTZV2EPW3T8GT2',
#    '4xlarge': 'HG3TP7M3FQZ54HKR',
#    'xlarge': 'Q3BP5KJZEPCUMKM3'},
#   'm3': {'2xlarge': 'P3CTRQJY7SHQ6BJR',
#    'large': 'JGXNGK5X7WE7K3VF',
#    'medium': 'UNEZG8PVCP3RUSQG',
#    'xlarge': 'QRP5VBPEA34W72YQ'},
#   'm4': {'10xlarge': 'PCKAVX9UQTRXBNNF',
#    '2xlarge': '8FFUWN2ESZYSB84N',
#    '4xlarge': 'BNSCBCWPZHWPDKKS',
#    'large': '7X4K64YA59VZZAC3',
#    'xlarge': '6FU9JEK79WWSARQ9'},
#   'r3': {'2xlarge': 'CP6AQ5U62SXMQV9P',
#    '4xlarge': 'PR4SS7VH54V5XAZZ',
#    '8xlarge': 'PY52HJB9NWEKKBZK',
#    'large': 'C3M6ZGSU66GC75NF',
#    'xlarge': 'VPAFYT3KA5TFAK4M'},
#   't1': {'micro': 'DFX4Y9GW9C3HE99V'},
#   't2': {'large': '4G2Z3WVSPDEGMKFH',
#    'medium': 'HF7N6NNE7N8GDMBE',
#    'micro': 'STTHYT3WDDQU8UBR',
#    'small': 'N6KDUVR23T758UUC'}},
#  'South America (Sao Paulo)': {'c1': {'medium': 'FSDH6G8FD9Z6EUM2',
#    'xlarge': 'HKWECXA9X8UKDCGK'},
#   'c3': {'2xlarge': 'SUWWGGR72MSFMMCK',
#    '4xlarge': 'DE4F8GSMG9ZHARG8',
#    '8xlarge': 'SHPTTVUVD5P7R2FX',
#    'large': 'H8BY38DSCNH87FAD',
#    'xlarge': 'AGV5N34XYJNRXKRG'},
#   'm1': {'large': '72TGAF9QN2XH5C5V',
#    'medium': '6TN6BMN8S44CMRDW',
#    'small': 'M6GCPQTQDNQK5XUW',
#    'xlarge': '8VWG8TTVN5G378AH'},
#   'm2': {'2xlarge': 'PDY52X9T9DZY9CT5',
#    '4xlarge': 'CSJECZGEN7MJ4PNS',
#    'xlarge': 'EY7JV9JX6H66P24B'},
#   'm3': {'2xlarge': 'B6W433SSVKEY68BH',
#    'large': 'CPGF97CV44XU5R37',
#    'medium': 'ADMZJH7G4TK3XW72',
#    'xlarge': 'FDUDDQXMYRBXXPU6'},
#   'r3': {'4xlarge': 'WCYXWR44SF5RDQSK', '8xlarge': 'YW6RW65SRZ3Y2FP5'},
#   't1': {'micro': 'MD2REDTVEQDNK4XJ'},
#   't2': {'large': '3AW2EEGJZNBGCQTC',
#    'medium': 'TRBTF7WUCDPWNYFM',
#    'micro': 'HR6CM3GFVDT3BAMU',
#    'small': '84JB45JJDJXM67K4'}},
#  'US East (N. Virginia)': {'c1': {'medium': 'X4RWGEB2DKQGCWC2',
#    'xlarge': '6TEX73KEE94WMEED'},
#   'c3': {'2xlarge': 'ZA47RH8PF27SDZKP',
#    '4xlarge': 'B4JUK3U7ZG63RGSF',
#    '8xlarge': 'H6T3SYB5G6QCVMZM',
#    'large': 'H48ZRU3X7FXGTGQM',
#    'xlarge': 'GEDBVWHPGWMPYFMC'},
#   'c4': {'2xlarge': '39748UVFEUKY3MVQ',
#    '4xlarge': 'ARPJFM962U4P5HAT',
#    '8xlarge': '9G23QA9CK3NU3BRY',
#    'large': '4C7N4APU9GEUZ6H6',
#    'xlarge': '4J62B76AXGGMHG57'},
#   'cc2': {'8xlarge': '3DX9M63484ZSZFJV'},
#   'cg1': {'4xlarge': 'NF67K4WANEWZZV22'},
#   'cr1': {'8xlarge': '3RUU5T58T7XAFAAF'},
#   'd2': {'2xlarge': 'P63NKZQXED5H7HUK',
#    '4xlarge': 'ZJC9VZJF5NZNYSVK',
#    '8xlarge': 'XP5P8NMSB2W7KP3U',
#    'xlarge': 'U7343ZA6ABZUXFZ9'},
#   'g2': {'2xlarge': '48VURD6MVAZ3M5JX', '8xlarge': 'A67CJDV9B3YBP6N6'},
#   'hi1': {'4xlarge': 'RJZ63YZJGC58TPTS'},
#   'hs1': {'8xlarge': 'CRRB3H2DYHU6K9FV'},
#   'i2': {'2xlarge': 'MU4QGTJYWR6T73MZ',
#    '4xlarge': 'ZESHW7CZVERW2BN2',
#    '8xlarge': 'NARXYND9H74FTC7A',
#    'xlarge': '5KHB4S5E8M74C6ES'},
#   'm1': {'large': 'KG9YWSKMK27V6W6V',
#    'medium': 'YUXKRQ5SQSHVKD58',
#    'small': '2GCTBU78G22TGEXZ',
#    'xlarge': 'EYGMRBWWFGSQBSBZ'},
#   'm2': {'2xlarge': 'QCQ27AYFPSSTJG55',
#    '4xlarge': 'RKCQDTMY5DZS4JWT',
#    'xlarge': 'J6U6GMEFVH686HBN'},
#   'm3': {'2xlarge': 'QSNKQ8P78YXPTAH8',
#    'large': 'YGU2QZY8VPP94FSR',
#    'medium': 'ASDZTDFMC5425T7P',
#    'xlarge': 'A83EBS2T67UP72G2'},
#   'm4': {'10xlarge': 'J4T9ZF4AJ2DXE7SA',
#    '2xlarge': 'VHC3YWSZ6ZFZPJN4',
#    '4xlarge': '3UP33R2RXCADSPSX',
#    'large': '8VCNEHQMSCQS4P39',
#    'xlarge': '47GP959QAF69YPG5'},
#   'r3': {'2xlarge': 'D5JBSPHEHDXDUWJR',
#    '4xlarge': 'RSN2RZ8JSX98HFVM',
#    '8xlarge': '4TCUDNKW7PMPSUT2',
#    'large': 'U3KDJRF6FGANNG5Z',
#    'xlarge': 'J5XXRJGFYZHJVQZJ'},
#   't1': {'micro': '639ZEB9D49ASFB26'},
#   't2': {'large': 'QG5G45WKDWDDHTFV',
#    'medium': 'QY3YSEST3C6FQNQH',
#    'micro': 'HZC9FAP4F9Y8JW67',
#    'small': 'VA8Q43DVPX4YV6NG'}},
#  'US West (N. California)': {'c1': {'medium': 'XFDUQKGKAPWHG6P5',
#    'xlarge': 'ZXWJ6NZFPEP89DVZ'},
#   'c3': {'2xlarge': '7QXMEKWFBRKXCR5T',
#    '4xlarge': 'PSNEQGH9XVX3FSE8',
#    '8xlarge': '4GAV6VD5FWD8W8B4',
#    'large': 'H8QFMXWT89NGP6VU',
#    'xlarge': 'S6XCDNADM5DDPNUP'},
#   'c4': {'2xlarge': 'G3EQX8J7UNTWEVC7',
#    '4xlarge': 'FA7B379WCHNBVMNU',
#    '8xlarge': 'GSN36ZXJH466ES5F',
#    'large': 'PYE3YUCCZCUBD7Z6',
#    'xlarge': 'JUT2GARXC5CE93CM'},
#   'g2': {'2xlarge': '87ZU79BG86PYWTSG', '8xlarge': '2M44JQQN3ZP9874A'},
#   'i2': {'2xlarge': 'TMYBBH8MNS5KCXDG',
#    '4xlarge': '8XWJMTS7HY3XFPBD',
#    '8xlarge': '3CUFXRHG38QDZNHT',
#    'xlarge': 'X7EQJS6PVD6RDBPD'},
#   'm1': {'large': 'GRGVZYA9QN53ASFB',
#    'medium': '7AJJ9ANNCNNX5WY6',
#    'small': 'P5VFWENV9YDAQVFH',
#    'xlarge': 'JJRB8PAXGN6JTB3D'},
#   'm2': {'2xlarge': 'VZA22HBW4H82PHGF',
#    '4xlarge': '6H5EA7PH345UPBVC',
#    'xlarge': 'XKAXY7525KWTBXQJ'},
#   'm3': {'2xlarge': 'CTG879VYY65QE94C',
#    'large': '8RXDZ4H62GHK7Y7N',
#    'medium': 'RT9NWVFZWQDDRNES',
#    'xlarge': 'EVYB78ZE853DF3CC'},
#   'm4': {'10xlarge': 'S7T2R43H93585V7D',
#    '2xlarge': '5JQZHK4R7B7U6R3D',
#    '4xlarge': 'F5KDHTDT282JC5R3',
#    'large': '3MU3SGMJKBFABKE9',
#    'xlarge': '2EBX6PMG5FBY92KC'},
#   'r3': {'2xlarge': 'VZ7V29X35F98VENC',
#    '4xlarge': 'J5UNF2XTPQCS5N59',
#    '8xlarge': 'CTW2PCJK622MCHPV',
#    'large': 'YY26V92H8QNEPQER',
#    'xlarge': 'RMARGSE4CA952UDV'},
#   't1': {'micro': '5JEH726H8KDYDWPP'},
#   't2': {'large': 'D7EXY7CNAHW9BTHD',
#    'medium': '7T9BSUQBURKAGP2T',
#    'micro': 'J6T772QKJ5B49GMC',
#    'small': 'JHV4BKWFVMXQ2T6R'}},
#  'US West (Oregon)': {'c1': {'medium': 'P9ZPWZF7CCR7MS77',
#    'xlarge': '5EPUM8UK2RTQKW5E'},
#   'c3': {'2xlarge': 'F6544RN8RCJHYC5Z',
#    '4xlarge': '9GHZN7VCNV2MGV4N',
#    '8xlarge': 'MNG2Y3YRJK7GPKQR',
#    'large': '672XUMHHEC7SYFT7',
#    'xlarge': '9NSBRG2FE96XPHXK'},
#   'c4': {'2xlarge': 'YBN8Q7AQJD9ZT57S',
#    '4xlarge': '3FTJBHZMWT7D76MD',
#    '8xlarge': 'UNB4R4KS4XXHQFD2',
#    'large': 'K24TXC5VMFQZ53MC',
#    'xlarge': '584JD8RT9GR57BFS'},
#   'cc2': {'8xlarge': '6P434MFC33XNF65Z'},
#   'cr1': {'8xlarge': 'PWGQ6MKD7A6EHVXN'},
#   'd2': {'2xlarge': '9RYWCN75CJX2C238',
#    '4xlarge': 'BNBBBYA6WNXQ3TZV',
#    '8xlarge': 'DW2RY9FQP8VE6V74',
#    'xlarge': 'YMWQW8W92QHE628D'},
#   'g2': {'2xlarge': 'QBRGX479S7RZ4QEA', '8xlarge': '7528XD9PPHXN6NN2'},
#   'hi1': {'4xlarge': 'K5MSZ8JUCECB23H9'},
#   'hs1': {'8xlarge': 'DTDPGWV4T5RAVP44'},
#   'i2': {'2xlarge': 'ZKYE77DHMC32Y9BK',
#    '4xlarge': '9HMZJQ3SKEW4P7ST',
#    '8xlarge': 'AKWXS6FJQE43VAZ9',
#    'xlarge': 'N5F93UFYUKWKB8KE'},
#   'm1': {'large': 'CVFJSWADA39YVNW2',
#    'medium': '2JUMD5V8V9V6D9JC',
#    'small': 'D8RPR5AJPDXSC9DF',
#    'xlarge': '4SCSPCTHFCXYY6GT'},
#   'm2': {'2xlarge': '5WF4ZHD94FEY4YDX',
#    '4xlarge': 'QBYJCF2RGQTF5H5D',
#    'xlarge': 'KCTVWQQPE9VFXHGP'},
#   'm3': {'2xlarge': 'CP2TNWZCKSRY486E',
#    'large': 'E7T5V224CMC9A43F',
#    'medium': 'JH68FQ55JWMC4CG9',
#    'xlarge': 'VBKTV5SAFT4WNV9X'},
#   'm4': {'10xlarge': 'MWG952JV6DF8YBYE',
#    '2xlarge': 'J9H28ZVG9UDW7CX4',
#    '4xlarge': 'BMEYUTP658QKQRTP',
#    'large': 'B2M25Y2U9824Q5TG',
#    'xlarge': 'X5NPE8XF7KHV7AAD'},
#   'r3': {'2xlarge': 'GMTWE5CTY4FEUYDN',
#    '4xlarge': 'JNZ6ESS4AS6RFUAF',
#    '8xlarge': 'NA6BZ2FSPKCZGWTA',
#    'large': '7RMRB492WTPDQ5Z4',
#    'xlarge': 'MBANS55WTSZ5HYS8'},
#   't1': {'micro': 'XUTTHNZ5B5VJKKDE'},
#   't2': {'large': 'WE87HQHP89BK3AXK',
#    'medium': '2ES9C4RF3WGQZAQN',
#    'micro': 'N4D3MGNKSH7Q9KT3',
#    'small': 'XK9YF9AJ9EBH7W4U'}}}

# %%
# {p['attributes']['operation'] for p in products.values()}
[p for p in products_categorized.values() if p['attributes']['operation']]
# Out:
# [{'attributes': {'clockSpeed': '2.4  GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '750 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm4.xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (N. California)',
#    'locationType': 'AWS Region',
#    'memory': '16 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2676 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'USW1-BoxUsage:m4.xlarge',
#    'vcpu': '4'},
#   'productFamily': 'Compute Instance',
#   'sku': '2EBX6PMG5FBY92KC'},
#  {'attributes': {'clockSpeed': '2.6 GHz',
#    'currentGeneration': 'No',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'cc2.8xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (Oregon)',
#    'locationType': 'AWS Region',
#    'memory': '60.5 GiB',
#    'networkPerformance': '10 Gigabit',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '4 x 840',
#    'tenancy': 'Shared',
#    'usagetype': 'USW2-BoxUsage:cc2.8xlarge',
#    'vcpu': '32'},
#   'productFamily': 'Compute Instance',
#   'sku': '6P434MFC33XNF65Z'},
#  {'attributes': {'clockSpeed': '2.8 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c3.large',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Singapore)',
#    'locationType': 'AWS Region',
#    'memory': '3.75 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2680 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '32-bit or 64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 16 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'APS1-BoxUsage:c3.large',
#    'vcpu': '2'},
#   'productFamily': 'Compute Instance',
#   'sku': 'ABMNUJ6SQ7A595A4'},
#  {'attributes': {'clockSpeed': '2.8 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c3.2xlarge',
#    'licenseModel': 'No License required',
#    'location': 'EU (Frankfurt)',
#    'locationType': 'AWS Region',
#    'memory': '15 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2680 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 80 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'EUC1-BoxUsage:c3.2xlarge',
#    'vcpu': '8'},
#   'productFamily': 'Compute Instance',
#   'sku': 'MB3JDB58W76ZHFT8'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm3.medium',
#    'licenseModel': 'No License required',
#    'location': 'South America (Sao Paulo)',
#    'locationType': 'AWS Region',
#    'memory': '3.75 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge/Sandy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '1 x 4 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'SAE1-BoxUsage:m3.medium',
#    'vcpu': '1'},
#   'productFamily': 'Compute Instance',
#   'sku': 'ADMZJH7G4TK3XW72'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Storage optimized',
#    'instanceType': 'i2.2xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Tokyo)',
#    'locationType': 'AWS Region',
#    'memory': '61 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 800 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'APN1-BoxUsage:i2.2xlarge',
#    'vcpu': '8'},
#   'productFamily': 'Compute Instance',
#   'sku': 'KM8DYQWHEC32CGGX'},
#  {'attributes': {'clockSpeed': '2.9 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '4000 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c4.8xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (Oregon)',
#    'locationType': 'AWS Region',
#    'memory': '60 GiB',
#    'networkPerformance': '10 Gigabit',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2666 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'USW2-BoxUsage:c4.8xlarge',
#    'vcpu': '36'},
#   'productFamily': 'Compute Instance',
#   'sku': 'UNB4R4KS4XXHQFD2'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Memory optimized',
#    'instanceType': 'r3.8xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Sydney)',
#    'locationType': 'AWS Region',
#    'memory': '244 GiB',
#    'networkPerformance': '10 Gigabit',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 320 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'APS2-BoxUsage:r3.8xlarge',
#    'vcpu': '32'},
#   'productFamily': 'Compute Instance',
#   'sku': 'GKVR3QEC5B7WJXTD'},
#  {'attributes': {'currentGeneration': 'No',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm1.large',
#    'licenseModel': 'No License required',
#    'location': 'EU (Ireland)',
#    'locationType': 'AWS Region',
#    'memory': '7.5 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 420',
#    'tenancy': 'Shared',
#    'usagetype': 'EU-BoxUsage:m1.large',
#    'vcpu': '2'},
#   'productFamily': 'Compute Instance',
#   'sku': 'NSCRWEDQZZESFDFG'},
#  {'attributes': {'clockSpeed': '2.8 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c3.large',
#    'licenseModel': 'No License required',
#    'location': 'US West (Oregon)',
#    'locationType': 'AWS Region',
#    'memory': '3.75 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2680 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '32-bit or 64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 16 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'USW2-BoxUsage:c3.large',
#    'vcpu': '2'},
#   'productFamily': 'Compute Instance',
#   'sku': '672XUMHHEC7SYFT7'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Storage optimized',
#    'instanceType': 'i2.2xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Singapore)',
#    'locationType': 'AWS Region',
#    'memory': '61 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 800 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'APS1-BoxUsage:i2.2xlarge',
#    'vcpu': '8'},
#   'productFamily': 'Compute Instance',
#   'sku': 'DKFKKEAW78H8X64T'},
#  {'attributes': {'clockSpeed': '2.9 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '750 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c4.xlarge',
#    'licenseModel': 'No License required',
#    'location': 'EU (Frankfurt)',
#    'locationType': 'AWS Region',
#    'memory': '7.5 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2666 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'EUC1-BoxUsage:c4.xlarge',
#    'vcpu': '4'},
#   'productFamily': 'Compute Instance',
#   'sku': 'ZAC36C46HPYXADA7'},
#  {'attributes': {'currentGeneration': 'No',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm1.small',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Sydney)',
#    'locationType': 'AWS Region',
#    'memory': '1.7 GiB',
#    'networkPerformance': 'Low',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '32-bit or 64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '1 x 160',
#    'tenancy': 'Shared',
#    'usagetype': 'APS2-BoxUsage',
#    'vcpu': '1'},
#   'productFamily': 'Compute Instance',
#   'sku': 'VM2PFN8ME9595UGP'},
#  {'attributes': {'clockSpeed': '2.8 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c3.2xlarge',
#    'licenseModel': 'No License required',
#    'location': 'South America (Sao Paulo)',
#    'locationType': 'AWS Region',
#    'memory': '15 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2680 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 80 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'SAE1-BoxUsage:c3.2xlarge',
#    'vcpu': '8'},
#   'productFamily': 'Compute Instance',
#   'sku': 'SUWWGGR72MSFMMCK'},
#  {'attributes': {'clockSpeed': '2.4 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '2000 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm4.4xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (N. California)',
#    'locationType': 'AWS Region',
#    'memory': '64 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2676 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'USW1-BoxUsage:m4.4xlarge',
#    'vcpu': '16'},
#   'productFamily': 'Compute Instance',
#   'sku': 'F5KDHTDT282JC5R3'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Storage optimized',
#    'instanceType': 'i2.4xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (N. California)',
#    'locationType': 'AWS Region',
#    'memory': '122 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '4 x 800 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'USW1-BoxUsage:i2.4xlarge',
#    'vcpu': '16'},
#   'productFamily': 'Compute Instance',
#   'sku': '8XWJMTS7HY3XFPBD'},
#  {'attributes': {'currentGeneration': 'No',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm1.xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Singapore)',
#    'locationType': 'AWS Region',
#    'memory': '15 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '4 x 420',
#    'tenancy': 'Shared',
#    'usagetype': 'APS1-BoxUsage:m1.xlarge',
#    'vcpu': '4'},
#   'productFamily': 'Compute Instance',
#   'sku': '7TMGTEJPM5UPWQ8X'},
#  {'attributes': {'clockSpeed': '2.4 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '450 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm4.large',
#    'licenseModel': 'No License required',
#    'location': 'US West (N. California)',
#    'locationType': 'AWS Region',
#    'memory': '8 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2676 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'USW1-BoxUsage:m4.large',
#    'vcpu': '2'},
#   'productFamily': 'Compute Instance',
#   'sku': '3MU3SGMJKBFABKE9'},
#  {'attributes': {'clockSpeed': '2.8 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c3.2xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (Oregon)',
#    'locationType': 'AWS Region',
#    'memory': '15 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2680 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 80 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'USW2-BoxUsage:c3.2xlarge',
#    'vcpu': '8'},
#   'productFamily': 'Compute Instance',
#   'sku': 'F6544RN8RCJHYC5Z'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Storage optimized',
#    'instanceType': 'i2.8xlarge',
#    'licenseModel': 'No License required',
#    'location': 'EU (Frankfurt)',
#    'locationType': 'AWS Region',
#    'memory': '244 GiB',
#    'networkPerformance': '10 Gigabit',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '8 x 800 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'EUC1-BoxUsage:i2.8xlarge',
#    'vcpu': '32'},
#   'productFamily': 'Compute Instance',
#   'sku': 'SMTUMBHX6YKRBJQB'},
#  {'attributes': {'instanceFamily': 'Micro instances',
#    'instanceType': 't1.micro',
#    'licenseModel': 'No License required',
#    'location': 'US West (N. California)',
#    'locationType': 'AWS Region',
#    'memory': '0.613 GiB',
#    'networkPerformance': 'Very Low',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Variable',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '32-bit or 64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'USW1-BoxUsage:t1.micro',
#    'vcpu': '1'},
#   'productFamily': 'Compute Instance',
#   'sku': '5JEH726H8KDYDWPP'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Memory optimized',
#    'instanceType': 'r3.4xlarge',
#    'licenseModel': 'No License required',
#    'location': 'EU (Frankfurt)',
#    'locationType': 'AWS Region',
#    'memory': '122 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '1 x 320 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'EUC1-BoxUsage:r3.4xlarge',
#    'vcpu': '16'},
#   'productFamily': 'Compute Instance',
#   'sku': '3KCGMZRVWDY4AC5R'},
#  {'attributes': {'clockSpeed': 'Up to 3.3 GHz',
#    'instanceFamily': 'General purpose',
#    'instanceType': 't2.small',
#    'licenseModel': 'No License required',
#    'location': 'US West (Oregon)',
#    'locationType': 'AWS Region',
#    'memory': '2 GiB',
#    'networkPerformance': 'Low to Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '32-bit or 64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'USW2-BoxUsage:t2.small',
#    'vcpu': '1'},
#   'productFamily': 'Compute Instance',
#   'sku': 'XK9YF9AJ9EBH7W4U'},
#  {'attributes': {'clockSpeed': '2.4 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '1000 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm4.2xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Sydney)',
#    'locationType': 'AWS Region',
#    'memory': '32 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2676 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'APS2-BoxUsage:m4.2xlarge',
#    'vcpu': '8'},
#   'productFamily': 'Compute Instance',
#   'sku': '296YCXVCWAKPXKRE'},
#  {'attributes': {'clockSpeed': 'Up to 3.3 GHz',
#    'instanceFamily': 'General purpose',
#    'instanceType': 't2.micro',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Singapore)',
#    'locationType': 'AWS Region',
#    'memory': '1 GiB',
#    'networkPerformance': 'Low to Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '32-bit or 64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'APS1-BoxUsage:t2.micro',
#    'vcpu': '1'},
#   'productFamily': 'Compute Instance',
#   'sku': 'RZV9MRNEARCGY297'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm3.medium',
#    'licenseModel': 'No License required',
#    'location': 'US West (Oregon)',
#    'locationType': 'AWS Region',
#    'memory': '3.75 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge/Sandy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '1 x 4 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'USW2-BoxUsage:m3.medium',
#    'vcpu': '1'},
#   'productFamily': 'Compute Instance',
#   'sku': 'JH68FQ55JWMC4CG9'},
#  {'attributes': {'currentGeneration': 'No',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm1.medium',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Singapore)',
#    'locationType': 'AWS Region',
#    'memory': '3.75 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '32-bit or 64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '1 x 410',
#    'tenancy': 'Shared',
#    'usagetype': 'APS1-BoxUsage:m1.medium',
#    'vcpu': '1'},
#   'productFamily': 'Compute Instance',
#   'sku': '7FQD2RCMJSS57GFA'},
#  {'attributes': {'clockSpeed': '2.4 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '2000 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm4.4xlarge',
#    'licenseModel': 'No License required',
#    'location': 'EU (Frankfurt)',
#    'locationType': 'AWS Region',
#    'memory': '64 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2676 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'EUC1-BoxUsage:m4.4xlarge',
#    'vcpu': '16'},
#   'productFamily': 'Compute Instance',
#   'sku': 'JGXEWM5NJCZJPHGG'},
#  {'attributes': {'clockSpeed': 'Up to 3.3 GHz',
#    'instanceFamily': 'General purpose',
#    'instanceType': 't2.small',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Singapore)',
#    'locationType': 'AWS Region',
#    'memory': '2 GiB',
#    'networkPerformance': 'Low to Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '32-bit or 64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'APS1-BoxUsage:t2.small',
#    'vcpu': '1'},
#   'productFamily': 'Compute Instance',
#   'sku': '7QHAUE39SCU6N9N9'},
#  {'attributes': {'clockSpeed': '2.4 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '450 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm4.large',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Sydney)',
#    'locationType': 'AWS Region',
#    'memory': '8 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2676 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'APS2-BoxUsage:m4.large',
#    'vcpu': '2'},
#   'productFamily': 'Compute Instance',
#   'sku': '6UMTMKVFBXENW3BF'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Memory optimized',
#    'instanceType': 'r3.4xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Sydney)',
#    'locationType': 'AWS Region',
#    'memory': '122 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '1 x 320 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'APS2-BoxUsage:r3.4xlarge',
#    'vcpu': '16'},
#   'productFamily': 'Compute Instance',
#   'sku': 'DBMRRDDSPZZKNV49'},
#  {'attributes': {'clockSpeed': '2.8 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c3.xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Sydney)',
#    'locationType': 'AWS Region',
#    'memory': '7.5 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2680 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 40 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'APS2-BoxUsage:c3.xlarge',
#    'vcpu': '4'},
#   'productFamily': 'Compute Instance',
#   'sku': 'XPAKDV3PWHYTJU3X'},
#  {'attributes': {'clockSpeed': '2.9 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '4000 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c4.8xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Sydney)',
#    'locationType': 'AWS Region',
#    'memory': '60 GiB',
#    'networkPerformance': '10 Gigabit',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2666 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'APS2-BoxUsage:c4.8xlarge',
#    'vcpu': '36'},
#   'productFamily': 'Compute Instance',
#   'sku': '46ZVWU6WX68NZCE7'},
#  {'attributes': {'clockSpeed': '2.9 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '500 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c4.large',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Sydney)',
#    'locationType': 'AWS Region',
#    'memory': '3.75 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2666 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'APS2-BoxUsage:c4.large',
#    'vcpu': '2'},
#   'productFamily': 'Compute Instance',
#   'sku': '2PKSXUFC38ZY888Q'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm3.xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (Oregon)',
#    'locationType': 'AWS Region',
#    'memory': '15 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge/Sandy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 40 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'USW2-BoxUsage:m3.xlarge',
#    'vcpu': '4'},
#   'productFamily': 'Compute Instance',
#   'sku': 'VBKTV5SAFT4WNV9X'},
#  {'attributes': {'clockSpeed': 'Up to 3.0 GHz',
#    'instanceFamily': 'General purpose',
#    'instanceType': 't2.large',
#    'licenseModel': 'No License required',
#    'location': 'EU (Ireland)',
#    'locationType': 'AWS Region',
#    'memory': '8 GiB',
#    'networkPerformance': 'Low to Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'EU-BoxUsage:t2.large',
#    'vcpu': '2'},
#   'productFamily': 'Compute Instance',
#   'sku': '4G2Z3WVSPDEGMKFH'},
#  {'attributes': {'currentGeneration': 'No',
#    'instanceFamily': 'Memory optimized',
#    'instanceType': 'm2.4xlarge',
#    'licenseModel': 'No License required',
#    'location': 'South America (Sao Paulo)',
#    'locationType': 'AWS Region',
#    'memory': '68.4 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 840',
#    'tenancy': 'Shared',
#    'usagetype': 'SAE1-BoxUsage:m2.4xlarge',
#    'vcpu': '8'},
#   'productFamily': 'Compute Instance',
#   'sku': 'CSJECZGEN7MJ4PNS'},
#  {'attributes': {'currentGeneration': 'No',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c1.xlarge',
#    'licenseModel': 'No License required',
#    'location': 'South America (Sao Paulo)',
#    'locationType': 'AWS Region',
#    'memory': '7 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '4 x 420',
#    'tenancy': 'Shared',
#    'usagetype': 'SAE1-BoxUsage:c1.xlarge',
#    'vcpu': '8'},
#   'productFamily': 'Compute Instance',
#   'sku': 'HKWECXA9X8UKDCGK'},
#  {'attributes': {'clockSpeed': 'Up to 3.0 GHz',
#    'instanceFamily': 'General purpose',
#    'instanceType': 't2.large',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Sydney)',
#    'locationType': 'AWS Region',
#    'memory': '8 GiB',
#    'networkPerformance': 'Low to Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'APS2-BoxUsage:t2.large',
#    'vcpu': '2'},
#   'productFamily': 'Compute Instance',
#   'sku': 'JT2PVSWTGS2BMV4D'},
#  {'attributes': {'clockSpeed': '2.9 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '1000 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c4.2xlarge',
#    'licenseModel': 'No License required',
#    'location': 'EU (Ireland)',
#    'locationType': 'AWS Region',
#    'memory': '15 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2666 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'EU-BoxUsage:c4.2xlarge',
#    'vcpu': '8'},
#   'productFamily': 'Compute Instance',
#   'sku': 'V2SRX3YBPSJPD8E4'},
#  {'attributes': {'clockSpeed': '2.4 GHz',
#    'currentGeneration': 'No',
#    'instanceFamily': 'Storage optimized',
#    'instanceType': 'hi1.4xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (Oregon)',
#    'locationType': 'AWS Region',
#    'memory': '60.5 GiB',
#    'networkPerformance': '10 Gigabit',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 1024 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'USW2-BoxUsage:hi1.4xlarge',
#    'vcpu': '16'},
#   'productFamily': 'Compute Instance',
#   'sku': 'K5MSZ8JUCECB23H9'},
#  {'attributes': {'clockSpeed': '2.4 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Storage optimized',
#    'instanceType': 'd2.2xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Singapore)',
#    'locationType': 'AWS Region',
#    'memory': '61 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2676v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '6 x 2000 HDD',
#    'tenancy': 'Shared',
#    'usagetype': 'APS1-BoxUsage:d2.2xlarge',
#    'vcpu': '8'},
#   'productFamily': 'Compute Instance',
#   'sku': 'SKTEJ2QN2YW8UFKF'},
#  {'attributes': {'clockSpeed': '2.8 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c3.8xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US East (N. Virginia)',
#    'locationType': 'AWS Region',
#    'memory': '60 GiB',
#    'networkPerformance': '10 Gigabit',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2680 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 320 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'BoxUsage:c3.8xlarge',
#    'vcpu': '32'},
#   'productFamily': 'Compute Instance',
#   'sku': 'H6T3SYB5G6QCVMZM'},
#  {'attributes': {'clockSpeed': '2.8 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c3.8xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (N. California)',
#    'locationType': 'AWS Region',
#    'memory': '60 GiB',
#    'networkPerformance': '10 Gigabit',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2680 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 320 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'USW1-BoxUsage:c3.8xlarge',
#    'vcpu': '32'},
#   'productFamily': 'Compute Instance',
#   'sku': '4GAV6VD5FWD8W8B4'},
#  {'attributes': {'clockSpeed': '2.8 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c3.8xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Sydney)',
#    'locationType': 'AWS Region',
#    'memory': '60 GiB',
#    'networkPerformance': '10 Gigabit',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2680 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 320 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'APS2-BoxUsage:c3.8xlarge',
#    'vcpu': '32'},
#   'productFamily': 'Compute Instance',
#   'sku': 'FYMCPD2A3YBTSUPQ'},
#  {'attributes': {'clockSpeed': '2.4 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '450 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm4.large',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Singapore)',
#    'locationType': 'AWS Region',
#    'memory': '8 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2676 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'APS1-BoxUsage:m4.large',
#    'vcpu': '2'},
#   'productFamily': 'Compute Instance',
#   'sku': 'B9DFHMNNN499Z259'},
#  {'attributes': {'currentGeneration': 'No',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c1.medium',
#    'licenseModel': 'No License required',
#    'location': 'US West (Oregon)',
#    'locationType': 'AWS Region',
#    'memory': '1.7 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '32-bit or 64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '1 x 350',
#    'tenancy': 'Shared',
#    'usagetype': 'USW2-BoxUsage:c1.medium',
#    'vcpu': '2'},
#   'productFamily': 'Compute Instance',
#   'sku': 'P9ZPWZF7CCR7MS77'},
#  {'attributes': {'currentGeneration': 'No',
#    'instanceFamily': 'Memory optimized',
#    'instanceType': 'm2.4xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US East (N. Virginia)',
#    'locationType': 'AWS Region',
#    'memory': '68.4 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 840',
#    'tenancy': 'Shared',
#    'usagetype': 'BoxUsage:m2.4xlarge',
#    'vcpu': '8'},
#   'productFamily': 'Compute Instance',
#   'sku': 'RKCQDTMY5DZS4JWT'},
#  {'attributes': {'currentGeneration': 'No',
#    'instanceFamily': 'Memory optimized',
#    'instanceType': 'm2.4xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Tokyo)',
#    'locationType': 'AWS Region',
#    'memory': '68.4 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 840',
#    'tenancy': 'Shared',
#    'usagetype': 'APN1-BoxUsage:m2.4xlarge',
#    'vcpu': '8'},
#   'productFamily': 'Compute Instance',
#   'sku': 'BQQUCAM9PFTSUNQX'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Memory optimized',
#    'instanceType': 'r3.xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (N. California)',
#    'locationType': 'AWS Region',
#    'memory': '30.5 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '1 x 80 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'USW1-BoxUsage:r3.xlarge',
#    'vcpu': '4'},
#   'productFamily': 'Compute Instance',
#   'sku': 'RMARGSE4CA952UDV'},
#  {'attributes': {'currentGeneration': 'No',
#    'instanceFamily': 'Memory optimized',
#    'instanceType': 'm2.2xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (N. California)',
#    'locationType': 'AWS Region',
#    'memory': '34.2 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '1 x 850',
#    'tenancy': 'Shared',
#    'usagetype': 'USW1-BoxUsage:m2.2xlarge',
#    'vcpu': '4'},
#   'productFamily': 'Compute Instance',
#   'sku': 'VZA22HBW4H82PHGF'},
#  {'attributes': {'clockSpeed': 'Up to 3.0 GHz',
#    'instanceFamily': 'General purpose',
#    'instanceType': 't2.large',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Tokyo)',
#    'locationType': 'AWS Region',
#    'memory': '8 GiB',
#    'networkPerformance': 'Low to Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'APN1-BoxUsage:t2.large',
#    'vcpu': '2'},
#   'productFamily': 'Compute Instance',
#   'sku': 'Q5HVB8NUA7UMHV4Y'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Memory optimized',
#    'instanceType': 'r3.8xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (N. California)',
#    'locationType': 'AWS Region',
#    'memory': '244 GiB',
#    'networkPerformance': '10 Gigabit',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 320 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'USW1-BoxUsage:r3.8xlarge',
#    'vcpu': '32'},
#   'productFamily': 'Compute Instance',
#   'sku': 'CTW2PCJK622MCHPV'},
#  {'attributes': {'clockSpeed': 'Up to 3.3 GHz',
#    'instanceFamily': 'General purpose',
#    'instanceType': 't2.micro',
#    'licenseModel': 'No License required',
#    'location': 'EU (Frankfurt)',
#    'locationType': 'AWS Region',
#    'memory': '1 GiB',
#    'networkPerformance': 'Low to Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '32-bit or 64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'EUC1-BoxUsage:t2.micro',
#    'vcpu': '1'},
#   'productFamily': 'Compute Instance',
#   'sku': 'T9GCN3NZ9U6N5BGN'},
#  {'attributes': {'currentGeneration': 'No',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm1.xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (N. California)',
#    'locationType': 'AWS Region',
#    'memory': '15 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '4 x 420',
#    'tenancy': 'Shared',
#    'usagetype': 'USW1-BoxUsage:m1.xlarge',
#    'vcpu': '4'},
#   'productFamily': 'Compute Instance',
#   'sku': 'JJRB8PAXGN6JTB3D'},
#  {'attributes': {'clockSpeed': '2.9 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '2000 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c4.4xlarge',
#    'licenseModel': 'No License required',
#    'location': 'EU (Ireland)',
#    'locationType': 'AWS Region',
#    'memory': '30 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2666 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'EU-BoxUsage:c4.4xlarge',
#    'vcpu': '16'},
#   'productFamily': 'Compute Instance',
#   'sku': 'BG8E99UBN6RZV6WV'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm3.medium',
#    'licenseModel': 'No License required',
#    'location': 'EU (Frankfurt)',
#    'locationType': 'AWS Region',
#    'memory': '3.75 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge/Sandy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '1 x 4 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'EUC1-BoxUsage:m3.medium',
#    'vcpu': '1'},
#   'productFamily': 'Compute Instance',
#   'sku': 'GDZZPNEEZXAN7X9J'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm3.large',
#    'licenseModel': 'No License required',
#    'location': 'US East (N. Virginia)',
#    'locationType': 'AWS Region',
#    'memory': '7.5 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge/Sandy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '1 x 32 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'BoxUsage:m3.large',
#    'vcpu': '2'},
#   'productFamily': 'Compute Instance',
#   'sku': 'YGU2QZY8VPP94FSR'},
#  {'attributes': {'currentGeneration': 'No',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm1.large',
#    'licenseModel': 'No License required',
#    'location': 'US West (Oregon)',
#    'locationType': 'AWS Region',
#    'memory': '7.5 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 420',
#    'tenancy': 'Shared',
#    'usagetype': 'USW2-BoxUsage:m1.large',
#    'vcpu': '2'},
#   'productFamily': 'Compute Instance',
#   'sku': 'CVFJSWADA39YVNW2'},
#  {'attributes': {'clockSpeed': '2.8 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c3.8xlarge',
#    'licenseModel': 'No License required',
#    'location': 'EU (Frankfurt)',
#    'locationType': 'AWS Region',
#    'memory': '60 GiB',
#    'networkPerformance': '10 Gigabit',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2680 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 320 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'EUC1-BoxUsage:c3.8xlarge',
#    'vcpu': '32'},
#   'productFamily': 'Compute Instance',
#   'sku': 'KYFX85FCPCCT57BD'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Storage optimized',
#    'instanceType': 'i2.4xlarge',
#    'licenseModel': 'No License required',
#    'location': 'EU (Frankfurt)',
#    'locationType': 'AWS Region',
#    'memory': '122 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '4 x 800 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'EUC1-BoxUsage:i2.4xlarge',
#    'vcpu': '16'},
#   'productFamily': 'Compute Instance',
#   'sku': '4TT65SC5HVYUSGR2'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Memory optimized',
#    'instanceType': 'r3.2xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US East (N. Virginia)',
#    'locationType': 'AWS Region',
#    'memory': '61 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
# ...
#    'physicalProcessor': 'Intel Xeon E5-2676v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '12 x 2000 HDD',
#    'tenancy': 'Shared',
#    'usagetype': 'BoxUsage:d2.4xlarge',
#    'vcpu': '16'},
#   'productFamily': 'Compute Instance',
#   'sku': 'ZJC9VZJF5NZNYSVK'},
#  {'attributes': {'clockSpeed': '2 GHz',
#    'currentGeneration': 'No',
#    'instanceFamily': 'Storage optimized',
#    'instanceType': 'hs1.8xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Singapore)',
#    'locationType': 'AWS Region',
#    'memory': '117 GiB',
#    'networkPerformance': '10 Gigabit',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2650',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '24 x 2000',
#    'tenancy': 'Shared',
#    'usagetype': 'APS1-BoxUsage:hs1.8xlarge',
#    'vcpu': '17'},
#   'productFamily': 'Compute Instance',
#   'sku': 'EERGZVYFKRBMSYKW'},
#  {'attributes': {'clockSpeed': 'Up to 3.3 GHz',
#    'instanceFamily': 'General purpose',
#    'instanceType': 't2.micro',
#    'licenseModel': 'No License required',
#    'location': 'South America (Sao Paulo)',
#    'locationType': 'AWS Region',
#    'memory': '1 GiB',
#    'networkPerformance': 'Low to Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '32-bit or 64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'SAE1-BoxUsage:t2.micro',
#    'vcpu': '1'},
#   'productFamily': 'Compute Instance',
#   'sku': 'HR6CM3GFVDT3BAMU'},
#  {'attributes': {'currentGeneration': 'No',
#    'instanceFamily': 'Memory optimized',
#    'instanceType': 'cr1.8xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Tokyo)',
#    'locationType': 'AWS Region',
#    'memory': '244 GiB',
#    'networkPerformance': '10 Gigabit',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 120 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'APN1-BoxUsage:cr1.8xlarge',
#    'vcpu': '32'},
#   'productFamily': 'Compute Instance',
#   'sku': 'GP8GQA2T96JQ4MBB'},
#  {'attributes': {'clockSpeed': '2.9 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '750 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c4.xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (Oregon)',
#    'locationType': 'AWS Region',
#    'memory': '7.5 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2666 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'USW2-BoxUsage:c4.xlarge',
#    'vcpu': '4'},
#   'productFamily': 'Compute Instance',
#   'sku': '584JD8RT9GR57BFS'},
#  {'attributes': {'clockSpeed': '2.9 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '2000 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c4.4xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (N. California)',
#    'locationType': 'AWS Region',
#    'memory': '30 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2666 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'USW1-BoxUsage:c4.4xlarge',
#    'vcpu': '16'},
#   'productFamily': 'Compute Instance',
#   'sku': 'FA7B379WCHNBVMNU'},
#  {'attributes': {'clockSpeed': '2.9 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '750 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c4.xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Singapore)',
#    'locationType': 'AWS Region',
#    'memory': '7.5 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2666 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'APS1-BoxUsage:c4.xlarge',
#    'vcpu': '4'},
#   'productFamily': 'Compute Instance',
#   'sku': 'U9CPUKN22CXMPGRV'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Storage optimized',
#    'instanceType': 'i2.xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Tokyo)',
#    'locationType': 'AWS Region',
#    'memory': '30.5 GiB',
#    'networkPerformance': 'Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '1 x 800 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'APN1-BoxUsage:i2.xlarge',
#    'vcpu': '4'},
#   'productFamily': 'Compute Instance',
#   'sku': 'EZCSGZJ8PMXA2QF2'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Memory optimized',
#    'instanceType': 'r3.8xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (Oregon)',
#    'locationType': 'AWS Region',
#    'memory': '244 GiB',
#    'networkPerformance': '10 Gigabit',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 320 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'USW2-BoxUsage:r3.8xlarge',
#    'vcpu': '32'},
#   'productFamily': 'Compute Instance',
#   'sku': 'NA6BZ2FSPKCZGWTA'},
#  {'attributes': {'clockSpeed': '2.6 GHz',
#    'currentGeneration': 'Yes',
#    'gpu': '1',
#    'instanceFamily': 'GPU instance',
#    'instanceType': 'g2.2xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Sydney)',
#    'locationType': 'AWS Region',
#    'memory': '15 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 (Sandy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '1 x 60 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'APS2-BoxUsage:g2.2xlarge',
#    'vcpu': '8'},
#   'productFamily': 'Compute Instance',
#   'sku': 'DS7EYGXHAG6T6NTV'},
#  {'attributes': {'clockSpeed': 'Up to 3.3 GHz',
#    'instanceFamily': 'General purpose',
#    'instanceType': 't2.small',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Sydney)',
#    'locationType': 'AWS Region',
#    'memory': '2 GiB',
#    'networkPerformance': 'Low to Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '32-bit or 64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'APS2-BoxUsage:t2.small',
#    'vcpu': '1'},
#   'productFamily': 'Compute Instance',
#   'sku': 'E6JQJZ8BQHCG328E'},
#  {'attributes': {'clockSpeed': '2.4 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '4000 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm4.10xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (Oregon)',
#    'locationType': 'AWS Region',
#    'memory': '160 GiB',
#    'networkPerformance': '10 Gigabit',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2676 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'USW2-BoxUsage:m4.10xlarge',
#    'vcpu': '40'},
#   'productFamily': 'Compute Instance',
#   'sku': 'MWG952JV6DF8YBYE'},
#  {'attributes': {'clockSpeed': 'Up to 3.3 GHz',
#    'instanceFamily': 'General purpose',
#    'instanceType': 't2.micro',
#    'licenseModel': 'No License required',
#    'location': 'US East (N. Virginia)',
#    'locationType': 'AWS Region',
#    'memory': '1 GiB',
#    'networkPerformance': 'Low to Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '32-bit or 64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'BoxUsage:t2.micro',
#    'vcpu': '1'},
#   'productFamily': 'Compute Instance',
#   'sku': 'HZC9FAP4F9Y8JW67'},
#  {'attributes': {'currentGeneration': 'No',
#    'instanceFamily': 'Memory optimized',
#    'instanceType': 'm2.4xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US West (Oregon)',
#    'locationType': 'AWS Region',
#    'memory': '68.4 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 840',
#    'tenancy': 'Shared',
#    'usagetype': 'USW2-BoxUsage:m2.4xlarge',
#    'vcpu': '8'},
#   'productFamily': 'Compute Instance',
#   'sku': 'QBYJCF2RGQTF5H5D'},
#  {'attributes': {'clockSpeed': '2.4  GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '750 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm4.xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US East (N. Virginia)',
#    'locationType': 'AWS Region',
#    'memory': '16 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2676 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'BoxUsage:m4.xlarge',
#    'vcpu': '4'},
#   'productFamily': 'Compute Instance',
#   'sku': '47GP959QAF69YPG5'},
#  {'attributes': {'clockSpeed': '2.9 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '2000 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c4.4xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Sydney)',
#    'locationType': 'AWS Region',
#    'memory': '30 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2666 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'APS2-BoxUsage:c4.4xlarge',
#    'vcpu': '16'},
#   'productFamily': 'Compute Instance',
#   'sku': 'F9BAR5QA2VU3ZTBF'},
#  {'attributes': {'clockSpeed': '2.9 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '750 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Compute optimized',
#    'instanceType': 'c4.xlarge',
#    'licenseModel': 'No License required',
#    'location': 'Asia Pacific (Sydney)',
#    'locationType': 'AWS Region',
#    'memory': '7.5 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2666 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'APS2-BoxUsage:c4.xlarge',
#    'vcpu': '4'},
#   'productFamily': 'Compute Instance',
#   'sku': 'XD4VKMMZMCMZYFWJ'},
#  {'attributes': {'currentGeneration': 'No',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm1.small',
#    'licenseModel': 'No License required',
#    'location': 'US East (N. Virginia)',
#    'locationType': 'AWS Region',
#    'memory': '1.7 GiB',
#    'networkPerformance': 'Low',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '32-bit or 64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '1 x 160',
#    'tenancy': 'Shared',
#    'usagetype': 'BoxUsage',
#    'vcpu': '1'},
#   'productFamily': 'Compute Instance',
#   'sku': '2GCTBU78G22TGEXZ'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm3.2xlarge',
#    'licenseModel': 'No License required',
#    'location': 'EU (Frankfurt)',
#    'locationType': 'AWS Region',
#    'memory': '30 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge/Sandy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 80 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'EUC1-BoxUsage:m3.2xlarge',
#    'vcpu': '8'},
#   'productFamily': 'Compute Instance',
#   'sku': 'CNP4PV4Y2J8YZVAR'},
#  {'attributes': {'currentGeneration': 'Yes',
#    'instanceFamily': 'GPU instance',
#    'instanceType': 'cg1.4xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US East (N. Virginia)',
#    'locationType': 'AWS Region',
#    'memory': '22.5 GiB',
#    'networkPerformance': '10 Gigabit',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon x5570',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 840',
#    'tenancy': 'Shared',
#    'usagetype': 'BoxUsage:cg1.4xlarge',
#    'vcpu': '16'},
#   'productFamily': 'Compute Instance',
#   'sku': 'NF67K4WANEWZZV22'},
#  {'attributes': {'clockSpeed': 'Up to 3.0 GHz',
#    'instanceFamily': 'General purpose',
#    'instanceType': 't2.large',
#    'licenseModel': 'No License required',
#    'location': 'US East (N. Virginia)',
#    'locationType': 'AWS Region',
#    'memory': '8 GiB',
#    'networkPerformance': 'Low to Moderate',
#    'operatingSystem': 'Linux',
#    'operation': 'RunInstances',
#    'physicalProcessor': 'Intel Xeon Family',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'BoxUsage:t2.large',
#    'vcpu': '2'},
#   'productFamily': 'Compute Instance',
#   'sku': 'QG5G45WKDWDDHTFV'}]

# %%
[p for idx, p in zip(range(3), products.values())]
# Out:
# [{'attributes': {'clockSpeed': '2.4 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '1000 Mbps',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm4.2xlarge',
#    'licenseModel': 'Bring your own license',
#    'location': 'EU (Frankfurt)',
#    'locationType': 'AWS Region',
#    'memory': '32 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Windows',
#    'operation': 'RunInstances:0800',
#    'physicalProcessor': 'Intel Xeon E5-2676 v3 (Haswell)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel AVX2; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': 'EBS only',
#    'tenancy': 'Shared',
#    'usagetype': 'EUC1-BoxUsage:m4.2xlarge',
#    'vcpu': '8'},
#   'productFamily': 'Compute Instance',
#   'sku': '3A9TKKH86T7SYAF6'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Memory optimized',
#    'instanceType': 'r3.8xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US East (N. Virginia)',
#    'locationType': 'AWS Region',
#    'memory': '244 GiB',
#    'networkPerformance': '10 Gigabit',
#    'operatingSystem': 'RHEL',
#    'operation': 'RunInstances:0010',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge)',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '2 x 320 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'BoxUsage:r3.8xlarge',
#    'vcpu': '32'},
#   'productFamily': 'Compute Instance',
#   'sku': 'KNFTFJY262DHDG36'},
#  {'attributes': {'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'Memory optimized',
#    'instanceType': 'r3.2xlarge',
#    'licenseModel': 'License Included',
#    'location': 'EU (Frankfurt)',
#    'locationType': 'AWS Region',
#    'memory': '61 GiB',
#    'networkPerformance': 'High',
#    'operatingSystem': 'Windows',
#    'operation': 'RunInstances:0006',
#    'physicalProcessor': 'Intel Xeon E5-2670 v2 (Ivy Bridge)',
#    'preInstalledSw': 'SQL Std',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX; Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'storage': '1 x 160 SSD',
#    'tenancy': 'Shared',
#    'usagetype': 'EUC1-BoxUsage:r3.2xlarge',
#    'vcpu': '8'},
#   'productFamily': 'Compute Instance',
#   'sku': '5MXWZ5X5SMYKXB9S'}]

# %% [markdown]
# # Results

# %% [markdown]
# {{SERVICE_CODE}}

# %%
from IPython.display import display
plt.plot(range(1,5), range(1,5))
print()

# %% [markdown]
# # Notes

# %% [markdown]
# ## pricing['product'] sample

# %% [raw]
# {'attributes': {'currentGeneration': 'No',
#   'instanceFamily': 'Memory optimized',
#   'instanceType': 'm2.2xlarge',
#   'licenseModel': 'No License required',
#   'location': 'US East (N. Virginia)',
#   'locationType': 'AWS Region',
#   'memory': '34.2 GiB',
#   'networkPerformance': 'Moderate',
#   'operatingSystem': 'RHEL',
#   'operation': 'RunInstances:0010',
#   'physicalProcessor': 'Intel Xeon Family',
#   'preInstalledSw': 'NA',
#   'processorArchitecture': '64-bit',
#   'servicecode': 'AmazonEC2',
#   'storage': '1 x 850',
#   'tenancy': 'Dedicated',
#   'usagetype': 'DedicatedUsage:m2.2xlarge',
#   'vcpu': '4'},
#  'productFamily': 'Compute Instance',
#  'sku': 'XX2TZABY6QFVXNY9'}

# %% [raw]
# In [52]: {(p['attributes']['operatingSystem'], p['attributes']['preInstalledSw'], p['attributes']['licenseModel'], p['attributes']['operation']) for p in p_compute.values()}
# Out[52]:
# {('Linux', 'NA', 'No License required', 'RunInstances'),
#  ('NA', 'NA', 'NA', 'Hourly'),
#  ('RHEL', 'NA', 'No License required', 'RunInstances:0010'),
#  ('SUSE', 'NA', 'No License required', 'RunInstances:000g'),
#  ('Windows', 'NA', 'Bring your own license', 'RunInstances:0800'),
#  ('Windows', 'NA', 'License Included', 'RunInstances:0002'),
#  ('Windows', 'SQL Server Enterprise', 'License Included', 'RunInstances:0102'),
#  ('Windows', 'SQL Std', 'License Included', 'RunInstances:0006'),
#  ('Windows', 'SQL Web', 'License Included', 'RunInstances:0202')}
